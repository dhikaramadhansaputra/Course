# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"D:\Dhika Ramadhan Saputra\Data Analist\Course\Introduction into Data Analytics & Python Fundamental\dataset\raw\dataset\08_gap-every-five-years.tsv", sep="\t")
df.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
df['lifeExp'].mean()
# Out:
# 59.474439366197174

# %%
df['lifeExp'].median()
# Out:
# 60.7125

# %%
df['lifeExp'].mode()
# Out:
# 0    69.39
# Name: lifeExp, dtype: float64

# %%
a = 1,2,3,4,5,6,7
for i in a:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7

# %%
for i in range(10, 20, 3):
    print (i)
# Out:
# 10
# 13
# 16
# 19

# %%
for i in range(10, 20, 3):
    print (i, end=',')
# Out:
# 10,13,16,19,

# %%
def nama():
    return("Dhika Ramadhan Saputra")

print("nama :", nama())
# Out:
# nama : Dhika Ramadhan Saputra

# %%
def add(p,q):
    c = p+q
    return(c)

add(2,3)
# Out:
# 5

# %%
data = [1,2,3,3,14,14,2,42,35,26,24,673,57,346,347,37,45,4,5745,23]

def min_max(data):
    min_val = min(data)
    max_val = max(data)
    return(min_val, max_val)

min_max(data)
# Out:
# (1, 5745)

# %%
a = [1,2,3,4,5]

# %%
q1 = np.percentile(a, 25)
q2 = np.percentile(a, 50)
q3 = np.percentile(a, 75)

q1, q2, q3
# Out:
# (2.0, 3.0, 4.0)

# %%
# interquartile
iq = q3-q1
iq
# Out:
# 2.0

# %%
from matplotlib import pyplot as plt
plt.boxplot(df['lifeExp'], sym="x")
plt.show()
